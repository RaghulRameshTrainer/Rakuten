# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\DELL\Downloads\company.csv')

# %%
df
# Out:
#      Company   Age  Salary     Place Country  Gender
# 0        TCS  20.0     NaN   Chennai   India       0
# 1    Infosys  30.0     NaN    Mumbai   India       0
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# ..       ...   ...     ...       ...     ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [148 rows x 6 columns]

# %%
pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)

# %%
df
# Out:
#                        Company   Age  Salary       Place Country  Gender
# 0                          TCS  20.0     NaN     Chennai   India       0
# 1                      Infosys  30.0     NaN      Mumbai   India       0
# 2                          TCS  35.0  2300.0    Calcutta   India       0
# 3                      Infosys  40.0  3000.0       Delhi   India       0
# 4                          TCS  23.0  4000.0      Mumbai   India       0
# 5                      Infosys   NaN  5000.0    Calcutta   India       0
# 6                          TCS   NaN  6000.0     Chennai   India       1
# 7                      Infosys  23.0  7000.0      Mumbai   India       1
# 8                          TCS  34.0  8000.0    Calcutta   India       1
# 9                          CTS  45.0  9000.0       Delhi   India       0
# 10                         CTS  23.0     NaN      Mumbai   India       0
# 11                         CTS  34.0  1089.0    Calcutta   India       0
# ...

# %%
df.head()
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0

# %%
df.head(2)
# Out:
#    Company   Age  Salary    Place Country  Gender
# 0      TCS  20.0     NaN  Chennai   India       0
# 1  Infosys  30.0     NaN   Mumbai   India       0

# %%
df.head(3)
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0

# %%
df.tail()
# Out:
#      Company   Age  Salary     Place Country  Gender
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0

# %%
df.tail(10)
# Out:
#              Company   Age  Salary      Place Country  Gender
# 138              CTS  44.0  3033.0     Cochin   India       0
# 139       Congnizant  22.0  2934.0      Noida   India       0
# 140          Infosys  44.0  4034.0  Hyderabad   India       0
# 141              TCS  33.0  5034.0   Calcutta   India       0
# 142  Infosys Pvt Lmt  22.0  8202.0     Mumbai   India       0
# 143              TCS  33.0  9024.0   Calcutta   India       1
# 144          Infosys  22.0  8787.0   Calcutta   India       1
# 145          Infosys  44.0  4034.0      Delhi   India       1
# 146              TCS  33.0  5034.0     Mumbai   India       1
# 147          Infosys  22.0  8202.0     Cochin   India       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
#  4   Country  148 non-null    object
#  5   Gender   148 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.1+ KB

# %%
df.describe()
# Out:
#               Age       Salary      Gender
# count  130.000000   124.000000  148.000000
# mean    30.484615  5312.467742    0.222973
# std     11.096640  2573.764683    0.417654
# min      0.000000  1089.000000    0.000000
# 25%     22.000000  3030.000000    0.000000
# 50%     32.500000  5000.000000    0.000000
# 75%     37.750000  8000.000000    0.000000
# max     54.000000  9876.000000    1.000000

# %%
df.count()
# Out:
# Company    140
# Age        130
# Salary     124
# Place      134
# Country    148
# Gender     148
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 4

# %%
df[df.duplicated()]
# Out:
#      Company   Age  Salary     Place Country  Gender
# 84       CTS  43.0     NaN    Mumbai   India       0
# 130      TCS  21.0  4824.0    Mumbai   India       0
# 131  Infosys   NaN  5835.0    Mumbai   India       0
# 144  Infosys  22.0  8787.0  Calcutta   India       1

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144 entries, 0 to 147
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  136 non-null    object
#  1   Age      127 non-null    float64
#  2   Salary   121 non-null    float64
#  3   Place    130 non-null    object
#  4   Country  144 non-null    object
#  5   Gender   144 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.9+ KB

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %%
df['Company']
# Out:
# 0                            TCS
# 1                        Infosys
# 2                            TCS
# 3                        Infosys
# 4                            TCS
# 5                        Infosys
# 6                            TCS
# 7                        Infosys
# 8                            TCS
# 9                            CTS
# 10                           CTS
# 11                           CTS
# 12                           CTS
# 13                           CTS
# 14                       Infosys
# 15                           TCS
# 16                       Infosys
# 17                           TCS
# 18                           TCS
# 19                       Infosys
# 20                           TCS
# 21                       Infosys
# 22                           TCS
# 23                       Infosys
# 24                           TCS
# 25                       Infosys
# 26                           TCS
# 27                           CTS
# ...

# %%
df['Company'].value_counts()
# Out:
# TCS                          52
# Infosys                      43
# CTS                          35
# Tata Consultancy Services     2
# Congnizant                    2
# Infosys Pvt Lmt               2
# Name: Company, dtype: int64

# %%
df['Company'].replace({'Tata Consultancy Services':'TCS',
                      'Infosys Pvt Lmt':'Infosys',
                      'Congnizant':'CTS'}, inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19896\3018165541.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company'].replace({'Tata Consultancy Services':'TCS',

# %%
df['Company'].value_counts()
# Out:
# TCS        54
# Infosys    45
# CTS        37
# Name: Company, dtype: int64

# %%
df['Company'].isnull().sum()
# Out:
# 8

# %%
df['Company'].mode()[0]
# Out:
# 'TCS'

# %%
df['Company'].fillna(df['Company'].mode()[0], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19896\5373860.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company'].fillna(df['Company'].mode()[0], inplace=True)

# %%
df['Company'].isnull().sum()
# Out:
# 0

# %%
df['Company'].value_counts()
# Out:
# TCS        62
# Infosys    45
# CTS        37
# Name: Company, dtype: int64

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %%
df['Age'].isnull().sum()
# Out:
# 17

# %%
df['Age'].min()
# Out:
# 0.0

# %%
df['Age'].max()
# Out:
# 54.0

# %%
df['Age'].mean()
# Out:
# 30.52755905511811

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19896\694922604.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
df['Age'].min()
# Out:
# 0.0

# %%
def change_age(age):
    if age<=21:
        return 22.5
    else:
        return age

# %%
df['Age']=df['Age'].apply(change_age)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19896\106115669.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age']=df['Age'].apply(change_age)

# %%
df['Age'].min()
# Out:
# 22.0

# %%
df['Age'].max()
# Out:
# 54.0

# %%
df['Age'].mean()
# Out:
# 31.68380905511811

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %%
df.head(10)
# Out:
#    Company        Age  Salary     Place Country  Gender
# 0      TCS  22.500000     NaN   Chennai   India       0
# 1  Infosys  30.000000     NaN    Mumbai   India       0
# 2      TCS  35.000000  2300.0  Calcutta   India       0
# 3  Infosys  40.000000  3000.0     Delhi   India       0
# 4      TCS  23.000000  4000.0    Mumbai   India       0
# 5  Infosys  30.527559  5000.0  Calcutta   India       0
# 6      TCS  30.527559  6000.0   Chennai   India       1
# 7  Infosys  23.000000  7000.0    Mumbai   India       1
# 8      TCS  34.000000  8000.0  Calcutta   India       1
# 9      CTS  45.000000  9000.0     Delhi   India       0

# %%
df['Salary'].fillna(df['Salary'].mean(),inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19896\2738737218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salary'].fillna(df['Salary'].mean(),inplace=True)

# %%
df.head(10)
# Out:
#    Company        Age       Salary     Place Country  Gender
# 0      TCS  22.500000  5283.471074   Chennai   India       0
# 1  Infosys  30.000000  5283.471074    Mumbai   India       0
# 2      TCS  35.000000  2300.000000  Calcutta   India       0
# 3  Infosys  40.000000  3000.000000     Delhi   India       0
# 4      TCS  23.000000  4000.000000    Mumbai   India       0
# 5  Infosys  30.527559  5000.000000  Calcutta   India       0
# 6      TCS  30.527559  6000.000000   Chennai   India       1
# 7  Infosys  23.000000  7000.000000    Mumbai   India       1
# 8      TCS  34.000000  8000.000000  Calcutta   India       1
# 9      CTS  45.000000  9000.000000     Delhi   India       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144 entries, 0 to 147
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  144 non-null    object
#  1   Age      144 non-null    float64
#  2   Salary   144 non-null    float64
#  3   Place    130 non-null    object
#  4   Country  144 non-null    object
#  5   Gender   144 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.9+ KB

# %%
df['Place'].isnull().sum()
# Out:
# 14

# %%
df['Place']=df['Place'].fillna('GOA')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19896\3775412688.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Place']=df['Place'].fillna('GOA')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144 entries, 0 to 147
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  144 non-null    object
#  1   Age      144 non-null    float64
#  2   Salary   144 non-null    float64
#  3   Place    144 non-null    object
#  4   Country  144 non-null    object
#  5   Gender   144 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.9+ KB

# %%
df.drop(columns=["Country"], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19896\3759157389.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Country"], inplace=True)

# %%
df.head(10)
# Out:
#    Company        Age       Salary     Place  Gender
# 0      TCS  22.500000  5283.471074   Chennai       0
# 1  Infosys  30.000000  5283.471074    Mumbai       0
# 2      TCS  35.000000  2300.000000  Calcutta       0
# 3  Infosys  40.000000  3000.000000     Delhi       0
# 4      TCS  23.000000  4000.000000    Mumbai       0
# 5  Infosys  30.527559  5000.000000  Calcutta       0
# 6      TCS  30.527559  6000.000000   Chennai       1
# 7  Infosys  23.000000  7000.000000    Mumbai       1
# 8      TCS  34.000000  8000.000000  Calcutta       1
# 9      CTS  45.000000  9000.000000     Delhi       0

# %%
df['Gender']=df['Gender'].apply(lambda g: 'Male' if g==0 else 'Female')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19896\1892956887.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender']=df['Gender'].apply(lambda g: 'Male' if g==0 else 'Female')

# %%
df.head(10)
# Out:
#    Company        Age       Salary     Place  Gender
# 0      TCS  22.500000  5283.471074   Chennai    Male
# 1  Infosys  30.000000  5283.471074    Mumbai    Male
# 2      TCS  35.000000  2300.000000  Calcutta    Male
# 3  Infosys  40.000000  3000.000000     Delhi    Male
# 4      TCS  23.000000  4000.000000    Mumbai    Male
# 5  Infosys  30.527559  5000.000000  Calcutta    Male
# 6      TCS  30.527559  6000.000000   Chennai  Female
# 7  Infosys  23.000000  7000.000000    Mumbai  Female
# 8      TCS  34.000000  8000.000000  Calcutta  Female
# 9      CTS  45.000000  9000.000000     Delhi    Male

# %%
def get_category(sal):
    if sal >= 8000:
        return "High Paid"
    return "Less Paid"

# %%
df['Salary_Category']=df['Salary'].apply(get_category)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19896\668670373.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salary_Category']=df['Salary'].apply(get_category)

# %%
df
# Out:
#      Company        Age       Salary       Place  Gender Salary_Category
# 0        TCS  22.500000  5283.471074     Chennai    Male       Less Paid
# 1    Infosys  30.000000  5283.471074      Mumbai    Male       Less Paid
# 2        TCS  35.000000  2300.000000    Calcutta    Male       Less Paid
# 3    Infosys  40.000000  3000.000000       Delhi    Male       Less Paid
# 4        TCS  23.000000  4000.000000      Mumbai    Male       Less Paid
# 5    Infosys  30.527559  5000.000000    Calcutta    Male       Less Paid
# 6        TCS  30.527559  6000.000000     Chennai  Female       Less Paid
# 7    Infosys  23.000000  7000.000000      Mumbai  Female       Less Paid
# 8        TCS  34.000000  8000.000000    Calcutta  Female       High Paid
# 9        CTS  45.000000  9000.000000       Delhi    Male       High Paid
# 10       CTS  23.000000  5283.471074      Mumbai    Male       Less Paid
# 11       CTS  34.000000  1089.000000    Calcutta    Male       Less Paid
# ...

# %%
df.head()
# Out:
#    Company   Age       Salary     Place Gender Salary_Category
# 0      TCS  22.5  5283.471074   Chennai   Male       Less Paid
# 1  Infosys  30.0  5283.471074    Mumbai   Male       Less Paid
# 2      TCS  35.0  2300.000000  Calcutta   Male       Less Paid
# 3  Infosys  40.0  3000.000000     Delhi   Male       Less Paid
# 4      TCS  23.0  4000.000000    Mumbai   Male       Less Paid

# %%
df[(df['Company']=='Infosys') & (df['Place']=='Mumbai')]
# Out:
#      Company        Age       Salary   Place  Gender Salary_Category
# 1    Infosys  30.000000  5283.471074  Mumbai    Male       Less Paid
# 7    Infosys  23.000000  7000.000000  Mumbai  Female       Less Paid
# 19   Infosys  32.000000  5283.471074  Mumbai    Male       Less Paid
# 25   Infosys  23.000000  8943.000000  Mumbai  Female       High Paid
# 39   Infosys  41.000000  3000.000000  Mumbai    Male       Less Paid
# 59   Infosys  30.527559  5835.000000  Mumbai    Male       Less Paid
# 68   Infosys  43.000000  4034.000000  Mumbai    Male       Less Paid
# 93   Infosys  54.000000  3184.000000  Mumbai    Male       Less Paid
# 111  Infosys  22.500000  3234.000000  Mumbai    Male       Less Paid
# 122  Infosys  44.000000  3234.000000  Mumbai    Male       Less Paid
# 142  Infosys  22.000000  8202.000000  Mumbai    Male       High Paid

# %%
df[df['Salary']>9000]
# Out:
#     Company   Age  Salary       Place  Gender Salary_Category
# 27      CTS  45.0  9284.0       Delhi  Female       High Paid
# 28      CTS  23.0  9876.0      Mumbai  Female       High Paid
# 35      TCS  35.0  9024.0         GOA  Female       High Paid
# 63      CTS  41.0  9284.0         GOA  Female       High Paid
# 71      TCS  34.0  9024.0      Mumbai  Female       High Paid
# 99      CTS  44.0  9284.0  Podicherry  Female       High Paid
# 107     TCS  22.5  9024.0     Chennai  Female       High Paid
# 117     CTS  44.0  9876.0         GOA  Female       High Paid
# 135     CTS  40.0  9284.0    Calcutta  Female       High Paid
# 143     TCS  33.0  9024.0    Calcutta  Female       High Paid

# %% [markdown]
# # iloc and loc

# %%
df.iloc[100:110,0:3]
# Out:
#      Company   Age       Salary
# 101      CTS  22.5  2034.000000
# 102      CTS  44.0  5283.471074
# 103      CTS  22.0  2934.000000
# 104  Infosys  44.0  4034.000000
# 105      TCS  33.0  5034.000000
# 106  Infosys  22.0  8202.000000
# 107      TCS  22.5  9024.000000
# 108      TCS  33.0  5283.471074
# 109      TCS  33.0  5283.471074
# 110      TCS  33.0  2300.000000

# %%
df.head()
# Out:
#    Company   Age       Salary     Place Gender Salary_Category
# 0      TCS  22.5  5283.471074   Chennai   Male       Less Paid
# 1  Infosys  30.0  5283.471074    Mumbai   Male       Less Paid
# 2      TCS  35.0  2300.000000  Calcutta   Male       Less Paid
# 3  Infosys  40.0  3000.000000     Delhi   Male       Less Paid
# 4      TCS  23.0  4000.000000    Mumbai   Male       Less Paid

# %%
df.loc[100:110,['Place','Company','Salary_Category']]
# Out:
#           Place  Company Salary_Category
# 100      Cochin      CTS       Less Paid
# 101  Podicherry      CTS       Less Paid
# 102      Mumbai      CTS       Less Paid
# 103    Calcutta      CTS       Less Paid
# 104       Delhi  Infosys       Less Paid
# 105      Mumbai      TCS       Less Paid
# 106      Cochin  Infosys       High Paid
# 107     Chennai      TCS       High Paid
# 108      Mumbai      TCS       Less Paid
# 109    Calcutta      TCS       Less Paid
# 110       Delhi      TCS       Less Paid

# %%
df[(df['Company']=='Infosys') & (df['Place']!='Mumbai')]
# Out:
#      Company        Age       Salary       Place  Gender Salary_Category
# 3    Infosys  40.000000  3000.000000       Delhi    Male       Less Paid
# 5    Infosys  30.527559  5000.000000    Calcutta    Male       Less Paid
# 14   Infosys  40.000000  3000.000000    Calcutta    Male       Less Paid
# 16   Infosys  23.000000  3030.000000  Podicherry    Male       Less Paid
# 21   Infosys  50.000000  3184.000000       Delhi    Male       Less Paid
# 23   Infosys  30.527559  5835.000000      Cochin    Male       Less Paid
# 32   Infosys  45.000000  4034.000000    Calcutta    Male       Less Paid
# 34   Infosys  26.000000  8202.000000         GOA    Male       High Paid
# 41   Infosys  30.527559  5000.000000         GOA    Male       Less Paid
# 43   Infosys  25.000000  7000.000000         GOA    Male       Less Paid
# 50   Infosys  41.000000  3000.000000     Chennai    Male       Less Paid
# 52   Infosys  22.500000  3030.000000    Calcutta    Male       Less Paid
# ...

# %%
df
# Out:
#      Company        Age       Salary       Place  Gender Salary_Category
# 0        TCS  22.500000  5283.471074     Chennai    Male       Less Paid
# 1    Infosys  30.000000  5283.471074      Mumbai    Male       Less Paid
# 2        TCS  35.000000  2300.000000    Calcutta    Male       Less Paid
# 3    Infosys  40.000000  3000.000000       Delhi    Male       Less Paid
# 4        TCS  23.000000  4000.000000      Mumbai    Male       Less Paid
# 5    Infosys  30.527559  5000.000000    Calcutta    Male       Less Paid
# 6        TCS  30.527559  6000.000000     Chennai  Female       Less Paid
# 7    Infosys  23.000000  7000.000000      Mumbai  Female       Less Paid
# 8        TCS  34.000000  8000.000000    Calcutta  Female       High Paid
# 9        CTS  45.000000  9000.000000       Delhi    Male       High Paid
# 10       CTS  23.000000  5283.471074      Mumbai    Male       Less Paid
# 11       CTS  34.000000  1089.000000    Calcutta    Male       Less Paid
# ...

# %%
df.sort_values(by=['Salary'])
# Out:
#      Company        Age       Salary       Place  Gender Salary_Category
# 119      CTS  33.000000  1089.000000       Noida    Male       Less Paid
# 47       CTS  32.000000  1089.000000      Mumbai    Male       Less Paid
# 83       CTS  33.000000  1089.000000     Chennai    Male       Less Paid
# 11       CTS  34.000000  1089.000000    Calcutta    Male       Less Paid
# 49       CTS  22.500000  1234.000000      Cochin    Male       Less Paid
# 121      CTS  22.500000  1234.000000    Calcutta    Male       Less Paid
# 13       CTS  22.500000  1234.000000      Mumbai    Male       Less Paid
# 85       CTS  22.500000  1234.000000    Calcutta    Male       Less Paid
# 137      CTS  31.000000  2034.000000      Mumbai    Male       Less Paid
# 101      CTS  22.500000  2034.000000  Podicherry    Male       Less Paid
# 29       CTS  35.000000  2034.000000      Cochin    Male       Less Paid
# 65       CTS  31.000000  2034.000000   Hyderabad    Male       Less Paid
# ...

# %%
df.sort_values(by=['Salary','Age'],ascending=[False,True])
# Out:
#      Company        Age       Salary       Place  Gender Salary_Category
# 28       CTS  23.000000  9876.000000      Mumbai  Female       High Paid
# 117      CTS  44.000000  9876.000000         GOA  Female       High Paid
# 135      CTS  40.000000  9284.000000    Calcutta  Female       High Paid
# 63       CTS  41.000000  9284.000000         GOA  Female       High Paid
# 99       CTS  44.000000  9284.000000  Podicherry  Female       High Paid
# 27       CTS  45.000000  9284.000000       Delhi  Female       High Paid
# 107      TCS  22.500000  9024.000000     Chennai  Female       High Paid
# 143      TCS  33.000000  9024.000000    Calcutta  Female       High Paid
# 71       TCS  34.000000  9024.000000      Mumbai  Female       High Paid
# 35       TCS  35.000000  9024.000000         GOA  Female       High Paid
# 81       CTS  43.000000  9000.000000        Pune  Female       High Paid
# 9        CTS  45.000000  9000.000000       Delhi    Male       High Paid
# ...

# %%
df.groupby('Company')['Salary'].min()
# Out:
# Company
# CTS        1089.0
# Infosys    3000.0
# TCS        2300.0
# Name: Salary, dtype: float64

# %%
df.groupby('Company')['Salary'].max()
# Out:
# Company
# CTS        9876.0
# Infosys    8943.0
# TCS        9024.0
# Name: Salary, dtype: float64

# %%
aggregate_report=df.groupby(['Company','Place','Gender'])['Salary'].agg(['min','max','sum','mean'])

# %%
aggregate_report
# Out:
#                                    min          max           sum         mean
# Company Place      Gender
# CTS     Calcutta   Female  9284.000000  9284.000000   9284.000000  9284.000000
#                    Male    1089.000000  5283.471074  17057.942149  2842.990358
#         Chennai    Male    1089.000000  7654.000000  14026.471074  4675.490358
#         Cochin     Male    1234.000000  5283.471074  11584.471074  2896.117769
#         Delhi      Female  9284.000000  9284.000000   9284.000000  9284.000000
#                    Male    9000.000000  9000.000000   9000.000000  9000.000000
#         GOA        Female  9284.000000  9876.000000  19160.000000  9580.000000
#                    Male    5283.471074  5283.471074   5283.471074  5283.471074
#         Hyderabad  Female  9000.000000  9000.000000   9000.000000  9000.000000
#                    Male    2034.000000  5283.471074   7317.471074  3658.735537
#         Mumbai     Female  9876.000000  9876.000000   9876.000000  9876.000000
# ...

# %%
aggregate_report.to_csv(r'C:\Users\DELL\Desktop\AggData\Company_Salary.csv')
